# %%
Output exceeds the size limit. Open the full output data in a text editor
Route 1 (Load 47.0): 1 -> 37 -> 41 -> 15 -> 2 -> 4 -> 1 (Distance 95.94)
Route 2 (Load 47.0): 1 -> 5 -> 17 -> 16 -> 1 (Distance 50.34)
Route 3 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
Route 4 (Load 30.0): 1 -> 8 -> 7 -> 10 -> 1 (Distance 51.84)
Route 5 (Load 38.0): 1 -> 9 -> 35 -> 34 -> 1 (Distance 55.69)
Route 6 (Load 44.0): 1 -> 11 -> 32 -> 20 -> 1 (Distance 57.92)
Route 7 (Load 55.0): 1 -> 12 -> 79 -> 76 -> 1 (Distance 40.42)
Route 8 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
Route 9 (Load 27.0): 1 -> 73 -> 21 -> 57 -> 1 (Distance 41.62)
Route 10 (Load 41.0): 1 -> 56 -> 23 -> 25 -> 1 (Distance 58.85)
Route 11 (Load 36.0): 1 -> 69 -> 27 -> 53 -> 1 (Distance 20.97)
Route 12 (Load 56.0): 1 -> 28 -> 50 -> 31 -> 1 (Distance 45.89)
Route 13 (Load 48.0): 1 -> 78 -> 29 -> 68 -> 1 (Distance 40.36)
Route 14 (Load 36.0): 1 -> 51 -> 30 -> 70 -> 1 (Distance 35.31)
Route 15 (Load 64.0): 1 -> 81 -> 33 -> 77 -> 3 -> 1 (Distance 37.02)
Route 16 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
Route 17 (Load 58.0): 1 -> 67 -> 39 -> 55 -> 1 (Distance 51.76)
Route 18 (Load 20.0): 1 -> 46 -> 45 -> 60 -> 1 (Distance 40.5)
Route 19 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
Route 20 (Load 36.0): 1 -> 52 -> 58 -> 40 -> 1 (Distance 34.54)
Route 21 (Load 27.0): 1 -> 54 -> 80 -> 24 -> 1 (Distance 47.28)
Route 22 (Load 74.0): 1 -> 59 -> 42 -> 44 -> 91 -> 93 -> 1 (Distance 58.0)
Route 23 (Load 61.0): 1 -> 85 -> 61 -> 84 -> 1 (Distance 35.87)
Route 24 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
Route 25 (Load 22.0): 1 -> 64 -> 63 -> 90 -> 1 (Distance 51.14)
...
gen no:0
pop no:0
{37: {41, 2, 4, 15}, 4: {41, 2, 37, 15}, 41: {2, 4, 37, 15}, 2: {41, 4, 37, 15}, 15: {41, 2, 4, 37}, 16: {17, 5}, 5: {16, 17}, 17: {16, 5}, 13: {6}, 6: {13}, 7: {8, 10}, 8: {10, 7}, 10: {8, 7}, 35: {9, 34}, 34: {9, 35}, 9: {34, 35}, 32: {11, 20}, 20: {32, 11}, 11: {32, 20}, 79: {76, 12}, 12: {76, 79}, 76: {12, 79}, 26: {19}, 19: {26}, 73: {57, 21}, 57: {73, 21}, 21: {73, 57}, 23: {56, 25}, 25: {56, 23}, 56: {25, 23}, 69: {27, 53}, 53: {27, 69}, 27: {69, 53}, 31: {50, 28}, 50: {28, 31}, 28: {50, 31}, 68: {29, 78}, 78: {68, 29}, 29: {68, 78}, 51: {70, 30}, 30: {51, 70}, 70: {51, 30}, 33: {81, 3, 77}, 81: {33, 3, 77}, 3: {81, 77, 33}, 77: {81, 33, 3}, 49: {36}, 36: {49}, 67: {55, 39}, 55: {67, 39}, 39: {67, 55}, 46: {60, 45}, 45: {60, 46}, 60: {45, 46}, 48: {47}, 47: {48}, 52: {40, 58}, 40: {58, 52}, 58: {40, 52}, 80: {24, 54}, 24: {80, 54}, 54: {24, 80}, 44: {59, 42, 91, 93}, 42: {91, 59, 44, 93}, 93: {91, 42, 59, 44}, 59: {42, 91, 44, 93}, 91: {42, 59, 44, 93}, 84: {85, 61}, 85: {84, 61}, 61: {84, 85}, 62: {88}, 88: {62}, 64: {90, 63}, 90: {64, 63}, 63: {64, 90}, 66: {65, 71}, 71: {65, 66}, 65: {66, 71}, 72: {74, 75, 22}, 74: {72, 75, 22}, 75: {72, 74, 22}, 22: {72, 74, 75}, 18: {82, 94}, 82: {18, 94}, 94: {82, 18}, 89: {96, 83}, 83: {96, 89}, 96: {89, 83}, 100: {38, 43, 14, 86, 92}, 14: {100, 38, 43, 86, 92}, 38: {100, 43, 14, 86, 92}, 43: {100, 38, 14, 86, 92}, 92: {100, 38, 43, 14, 86}, 86: {100, 38, 43, 14, 92}, 98: {97, 99, 95, 87}, 95: {97, 98, 99, 87}, 99: {97, 98, 87, 95}, 97: {98, 99, 95, 87}, 87: {97, 98, 99, 95}}
current_customer:85

# %%
def distance(x1, y1, x2, y2):
    """
    Calculates the Euclidean distance between two points.
    """
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

# %%
def get_data_points(txt_file):
    ## Function to convert txt file into a pandas dataframe
    data = []
    with open(txt_file, "r") as file:
        lines = file.readlines()  # Read all lines in the file
        column_parsed = False
        column_names = []
        if column_parsed == False:
            words =  re.findall("\S+", lines[0])  # Extract column names from first line
            for word in words:
                column_names.append(word)   
            column_parsed=True                 
                
        for line in lines[1:]:  # Loop through lines, skipping the first line
            dataline = re.findall("\S+", line)  # Extract data points from line
            line_dict={}
            for i,point in enumerate(dataline):
                line_dict[column_names[i]]= float(point)  # Convert data point to float and store in dictionary
            data.append(line_dict)  # Append dictionary to list of data
    
    df = pd.DataFrame(data)   # Create pandas dataframe from list of dictionaries
    return df  # Return the dataframe

# %%
# Step 1: Initialize the data
customers = get_data_points("vrp data.txt")

# %%
# Step 2: Calculate the distance matrix between all customers
    # You can use the euclidean distance for example

def calculate_distance_matrix(customers):
    """
    Calculates the distance matrix between all customers.

    Args:
        customers: A pandas dataframe with columns [CUST_NO, XCOORD, YCOORD, DEMAND, READY_TIME, DUE_DATE, SERVICE_TIME].

    Returns:
        A numpy array representing the distance matrix between all customers.
    """
    # Create an empty numpy array to store the distance matrix
    n_customers = len(customers)
    dist_matrix = np.zeros((n_customers, n_customers))

    # Loop over each pair of customers
    for i in range(n_customers):
        for j in range(n_customers):
            # Calculate the Euclidean distance between the XCOORD and YCOORD values of the two customers
            x_diff = customers['XCOORD'][i] - customers['XCOORD'][j]
            y_diff = customers['YCOORD'][i] - customers['YCOORD'][j]
            dist = math.sqrt(math.pow(x_diff, 2) + math.pow(y_diff, 2))

            # Store the calculated distance in the corresponding position in the distance matrix
            dist_matrix[i][j] = dist

    return dist_matrix

# %%
def check_vehicle_capacity(customers, new_route):
    """
    Checks if adding the new_route to the existing routes would violate the vehicle capacity constraint
    
    Args:
        customers: A list of tuples representing customer data in the format:
            (cust_no, xcoord, ycoord, demand, ready_time, due_date, service_time)
        new_route: A list of customer numbers in the order they are visited
        
    Returns:
        True if adding the new_route would not violate the vehicle capacity constraint, False otherwise
    """
    capacity = 0
    for cust in new_route:
        capacity += customers.loc[cust,"DEMAND"] # demand of customer
        if capacity > 200:
            return False
    return True

# %%
def check_time_windows(customers, new_route):
    def distance(point1, point2):
      x1, y1 = point1
      x2, y2 = point2
      return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

    current_time = 0
    current_capacity = 0
    for i in range(len(new_route)):
        # Get the customer details
        cust = customers.loc[new_route[i]]
        xcoord, ycoord, demand, ready_time, due_date, service_time = cust[1:]
        
        # Calculate the travel time to the customer
        travel_time = distance((customers.loc[new_route[i-1], 'XCOORD'], customers.loc[new_route[i-1], 'YCOORD']), (xcoord, ycoord))
        
        # Calculate the time the customer will be serviced
        # service_start_time = max(current_time + travel_time, ready_time)
        service_start_time = max(current_time , ready_time)

        service_end_time = service_start_time + service_time
        
        # Check if the service time is within the customer's time window
        if service_end_time > due_date:
            return False
        
        # Update the current time and capacity
        current_time = service_end_time
        current_capacity += demand
        
        # Check if the capacity constraint is violated
        if current_capacity > 200:
            return False
    
    return True

# %%
def calculate_route_distance(customers, dist_matrix, route):
    """
    Calculates the total distance traveled on a given route
    
    Args:
        customers: A pandas dataframe representing customer data with the columns:
            CUST_NO, XCOORD, YCOORD, DEMAND, READY_TIME, DUE_DATE, SERVICE_TIME
        dist_matrix: A 2D numpy array representing the distance matrix between customers
        route: A list of customer numbers in the order they are visited
    
    Returns:
        The total distance traveled on the route
    """
    distance = 0
    for i in range(len(route) - 1):
        distance += dist_matrix[route[i], route[i+1]]
    distance += dist_matrix[route[-1], 0]
    return distance

# %%
def calculate_savings(customers, dist_matrix):
    """
    Calculates the savings for each pair of customers
    
    Args:
        customers: A pandas dataframe representing customer data with the columns:
            CUST_NO, XCOORD, YCOORD, DEMAND, READY_TIME, DUE_DATE, SERVICE_TIME
        dist_matrix: A 2D numpy array representing the distance matrix between customers
    
    Returns:
        A list of tuples representing the savings for each pair of customers, in descending order
    """
    # Calculate savings
    n_customers = len(customers)
    savings = []
    for i in range(2, n_customers):
        for j in range(i+1, n_customers):
            saving = dist_matrix[0][i] + dist_matrix[0][j] - dist_matrix[i][j]
            savings.append(((i,j), saving))
    
    # Sort savings in descending order
    sorted_savings = sorted(savings, key=lambda x: x[1], reverse=True)
    
    return sorted_savings

# %%
def get_vehicle_capacity(customers, new_route):
    """
    Checks if adding the new_route to the existing routes would violate the vehicle capacity constraint
    
    Args:
        customers: A list of tuples representing customer data in the format:
            (cust_no, xcoord, ycoord, demand, ready_time, due_date, service_time)
        new_route: A list of customer numbers in the order they are visited
        
    Returns:
        True if adding the new_route would not violate the vehicle capacity constraint, False otherwise
    """
    capacity = 0
    for cust in new_route:
        capacity += customers.loc[cust,"DEMAND"] # demand of customer
    return capacity

# %%
dist_matrix = calculate_distance_matrix(customers)

# Calculate savings
savings = calculate_savings(customers, dist_matrix)

# Sort savings in descending order
sorted_savings = sorted(savings, key=lambda x: x[1], reverse=True)

# %%
def clark_wright_savings(customers):
    """
    Applies Clark and Wright savings algorithm to generate initial solution
    
    Args:
        customers: A pandas dataframe representing customer data with the columns:
            CUST_NO, XCOORD, YCOORD, DEMAND, READY_TIME, DUE_DATE, SERVICE_TIME
    
    Returns:
        A list of routes, where each route is a list of customer numbers in the order they are visited
    """
    # Calculate distance matrix
    dist_matrix = calculate_distance_matrix(customers)
    
    # Calculate savings
    savings = calculate_savings(customers, dist_matrix)
    
    # Sort savings in descending order
    sorted_savings = sorted(savings, key=lambda x: x[1], reverse=True)

    # Initialize each customer as a separate route
    routes = [[i] for i in range(2, len(customers))]
    
    # Merge routes until vehicle capacity is maximized near its full capacity
    while any(get_vehicle_capacity(customers, r) < 200 - 10 for r in routes):
        merged = False
        for (i, j), s in sorted_savings:
            # Check if customers i and j are already in the same route
            i_route = None
            j_route = None
            for r in routes:
                if i in r:
                    i_route = r
                if j in r:
                    j_route = r
            if i_route == j_route:
                continue
                
            # Check if merging customers i and j would violate vehicle capacity or time windows
            new_route = i_route + j_route
            if check_vehicle_capacity(customers, new_route) and check_time_windows(customers, new_route):
                # Merge routes
                if i_route.index(i) == 0:
                    i_route.reverse()
                if j_route.index(j) == len(j_route) - 1:
                    j_route.reverse()
                i_route.extend(j_route)
                routes.remove(j_route)
                merged = True
        if not merged:
            break

    
    # Print routes and distances
    route_num = 1
    total_distance = 0
    new_routes = []
    for r in routes:
      if len(r)>=1:
        new_routes.append(r)

    for r in new_routes:
        route_str = f"Route {route_num} (Load {sum(customers.loc[r, 'DEMAND'])}): "
        route_str += " -> ".join([f"{int(c)}" for c in [1] + r + [1]])
        distance = calculate_route_distance(customers, dist_matrix, r)
        total_distance += distance
        route_str += f" (Distance {round(distance,2)})"
        print(route_str)
        route_num += 1
    
    # Print total distance and percentage of customers served
    print(f"Total distance: {round(total_distance,2)}")
    print(f"Percentage of customers served: {round(100 * len(set([c for r in new_routes for c in r])) / (len(customers)-2),2)}%")
      
    return new_routes

# %%
def calculate_total_distance(customers, dist_matrix, routes):
    """
    Calculates the total distance of a set of routes
    
    Args:
        customers: A pandas dataframe representing customer data with the columns:
            CUST_NO, XCOORD, YCOORD, DEMAND, READY_TIME, DUE_DATE, SERVICE_TIME
        dist_matrix: A numpy array representing the distance matrix between customers
        routes: A list of routes, where each route is a list of customer numbers in the order they are visited
    
    Returns:
        The total distance of the routes
    """
    total_distance = 0
    for r in routes:
        distance = calculate_route_distance(customers, dist_matrix, r)
        total_distance += distance
    return total_distance

# %%
def tournament_selection(population, fitness, k=3):
    """
    Selects an individual from a population using tournament selection
    
    Args:
        population: A list of individuals, where each individual is represented as a list
        fitness: A list of fitness values for each individual in the population
        k: The number of individuals to include in each tournament (default=3)
    
    Returns:
        The selected individual
    """

    tournament = random.sample(list(zip(population, fitness)), k)

    return max(tournament, key=lambda x: x[1])[0]

# %%
def order_crossover(parent1, parent2):
    """
    Applies order crossover to two parent solutions to generate two child solutions
    
    Args:
        parent1: A list representing a solution
        parent2: A list representing another solution
    
    Returns:
        Two lists representing child solutions
    """
    # Select two random indices to define the crossover segment
    i, j = sorted(random.sample(range(len(parent1)), 2))
    
    # Create two empty child solutions
    child1 = [None] * len(parent1)
    child2 = [None] * len(parent1)
    
    # Copy the crossover segment from parent 1 to child 1 and from parent 2 to child 2
    child1[i:j+1] = parent1[i:j+1]
    child2[i:j+1] = parent2[i:j+1]
    
    # Create a list of remaining elements in parent 2
    remaining = [e for e in parent2 if e not in child1]
    
    # Fill in the rest of child 1 with remaining elements in the order they appear in parent 2
    child1[:i] = [e for e in remaining[:i] if e not in child1]
    child1[j+1:] = [e for e in remaining[i:] if e not in child1]
    
    # Create a list of remaining elements in parent 1
    remaining = [e for e in parent1 if e not in child2]
    
    # Fill in the rest of child 2 with remaining elements in the order they appear in parent 1
    child2[:i] = [e for e in remaining[:i] if e not in child2]
    child2[j+1:] = [e for e in remaining[i:] if e not in child2]
    
    return child1, child2

# %%
def swap_mutation(solution, mutation_rate):
    """
    Perform swap mutation on a solution with given mutation rate
    
    Args:
        solution: A list of routes, where each route is a list of customer numbers in the order they are visited
        mutation_rate: A float representing the probability of mutation
        
    Returns:
        A new mutated solution
    """
    new_solution = []
    for route in solution:
        if route is not None:
            if len(route)>2:
                if random.random() < mutation_rate:
                    # Perform swap mutation on the current route
                    i, j = random.sample(range(1, len(route)), 2)
                    route[i], route[j] = route[j], route[i]
            new_solution.append(route)
    return new_solution

# %%
def formulate_solution(solution):
    route_num = 1
    total_distance = 0

    for r in solution:
        route_str = f"Route {route_num} (Load {sum(customers.loc[r, 'DEMAND'])}): "
        route_str += " -> ".join([f"{int(c)}" for c in [1] + r + [1]])
        distance = calculate_route_distance(customers, dist_matrix, r)
        total_distance += distance
        route_str += f" (Distance {round(distance,2)})"
        print(route_str)
        route_num += 1
        

    # Print total distance and percentage of customers served
    print(f"Total distance: {round(total_distance,2)}")
    print(f"Percentage of customers served: {round(100 * len(set([c for r in solution for c in r])) / (len(customers)-2),2)}%")

# %%
def check_solution_feasibility(customers,routes):
    new_routes1=[]
    for route in routes:
        if check_vehicle_capacity(customers, route) and check_time_windows(customers, route):
            new_routes1.append(route)
    
    new_routes = []
    for r in new_routes1:
      if len(r)>=1:
        new_routes.append(r)

    route_num = 1
    total_distance = 0
    for r in new_routes:
        route_str = f"Route {route_num} (Load {sum(customers.loc[r, 'DEMAND'])}): "
        route_str += " -> ".join([f"{int(c)}" for c in [1] + r + [1]])
        distance = calculate_route_distance(customers, dist_matrix, r)
        total_distance += distance
        route_str += f" (Distance {round(distance,2)})"
        print(route_str)
        route_num += 1
    

    # Print total distance and percentage of customers served
    print(f"Total distance: {round(total_distance,2)}")
    print(f"Percentage of customers served: {round(100 * len(set([c for r in new_routes for c in r])) / (len(customers)-2),2)}%")
      

    return new_routes

# %%
def all_customers_served(solution):
    """
    Checks if all customers have been served in a solution
    
    Args:
        solution: A list of routes, where each route is a list of customer numbers in the order they are visited
    
    Returns:
        True if all customers have been served, False otherwise
    """
    visited_customers = set()
    for route in solution:
        visited_customers.update(route)
    return visited_customers == set(range(len(customers)))

# %%
# Step 1: get initial solution

routes = clark_wright_savings(customers)

dist_matrix = calculate_distance_matrix(customers)



# Step 2: Define genetic algorithm parameters
POPULATION_SIZE = 20
NUM_GENERATIONS = 5
MUTATION_RATE = 0.5
CROSSOVER_RATE = 0.5

# Step 3: Generate initial population
population = []
for i in range(POPULATION_SIZE):
    shuffled_routes = [random.sample(route, len(route)) for route in routes]
    population.append(shuffled_routes)
# Out:
# Route 1 (Load 47.0): 1 -> 37 -> 41 -> 15 -> 2 -> 4 -> 1 (Distance 95.94)
# Route 2 (Load 47.0): 1 -> 5 -> 17 -> 16 -> 1 (Distance 50.34)
# Route 3 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 4 (Load 30.0): 1 -> 8 -> 7 -> 10 -> 1 (Distance 51.84)
# Route 5 (Load 38.0): 1 -> 9 -> 35 -> 34 -> 1 (Distance 55.69)
# Route 6 (Load 44.0): 1 -> 11 -> 32 -> 20 -> 1 (Distance 57.92)
# Route 7 (Load 55.0): 1 -> 12 -> 79 -> 76 -> 1 (Distance 40.42)
# Route 8 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 9 (Load 27.0): 1 -> 73 -> 21 -> 57 -> 1 (Distance 41.62)
# Route 10 (Load 41.0): 1 -> 56 -> 23 -> 25 -> 1 (Distance 58.85)
# Route 11 (Load 36.0): 1 -> 69 -> 27 -> 53 -> 1 (Distance 20.97)
# Route 12 (Load 56.0): 1 -> 28 -> 50 -> 31 -> 1 (Distance 45.89)
# Route 13 (Load 48.0): 1 -> 78 -> 29 -> 68 -> 1 (Distance 40.36)
# Route 14 (Load 36.0): 1 -> 51 -> 30 -> 70 -> 1 (Distance 35.31)
# Route 15 (Load 64.0): 1 -> 81 -> 33 -> 77 -> 3 -> 1 (Distance 37.02)
# Route 16 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 17 (Load 58.0): 1 -> 67 -> 39 -> 55 -> 1 (Distance 51.76)
# Route 18 (Load 20.0): 1 -> 46 -> 45 -> 60 -> 1 (Distance 40.5)
# Route 19 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 20 (Load 36.0): 1 -> 52 -> 58 -> 40 -> 1 (Distance 34.54)
# Route 21 (Load 27.0): 1 -> 54 -> 80 -> 24 -> 1 (Distance 47.28)
# Route 22 (Load 74.0): 1 -> 59 -> 42 -> 44 -> 91 -> 93 -> 1 (Distance 58.0)
# Route 23 (Load 61.0): 1 -> 85 -> 61 -> 84 -> 1 (Distance 35.87)
# Route 24 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 25 (Load 22.0): 1 -> 64 -> 63 -> 90 -> 1 (Distance 51.14)
# Route 26 (Load 60.0): 1 -> 71 -> 65 -> 66 -> 1 (Distance 64.39)
# Route 27 (Load 69.0): 1 -> 75 -> 72 -> 74 -> 22 -> 1 (Distance 38.64)
# Route 28 (Load 55.0): 1 -> 82 -> 94 -> 18 -> 1 (Distance 52.95)
# Route 29 (Load 37.0): 1 -> 96 -> 83 -> 89 -> 1 (Distance 33.97)
# Route 30 (Load 97.0): 1 -> 92 -> 100 -> 43 -> 86 -> 38 -> 14 -> 1 (Distance 101.91)
# Route 31 (Load 77.0): 1 -> 99 -> 98 -> 95 -> 97 -> 87 -> 1 (Distance 37.43)
# Total distance: 1465.08
# Percentage of customers served: 100.0%

# %%
# Step 5: Implement selection, crossover, and mutation operators
best_solution = None
for generation in range(NUM_GENERATIONS):
    print(f"gen no:{generation}")
    # Step 5.1: Selection operator (e.g., tournament selection)
    new_population = []
    for i in range(POPULATION_SIZE):
        print(f"pop no:{i}")
        
        fitness = [calculate_total_distance(customers, dist_matrix, solution) for solution in population]
        parent1 = tournament_selection(population, fitness, k=3)
        parent2 = tournament_selection(population, fitness, k=3)
        


        if random.random() < CROSSOVER_RATE:
            child1, child2 = order_crossover(parent1, parent2)
            child = random.choice([child1, child2])
        else:
            child = parent1

        

        # Step 5.3: Mutation operator (e.g., swap mutation)
        child = swap_mutation(child,MUTATION_RATE)


        new_population.append(child)
    
    feasible_population = []
    # Step 6: Evaluate fitness of new population
    best_solution_in_generated_pop = None
    for solution in new_population:
        feasible_solution = check_solution_feasibility(customers, solution)
        new_fitness = calculate_total_distance(customers, dist_matrix, feasible_solution)
        feasible_population.append(feasible_solution)
        if best_solution_in_generated_pop is None or new_fitness < calculate_total_distance(customers, dist_matrix, best_solution_in_generated_pop):
            best_solution_in_generated_pop = feasible_solution

    if best_solution is None or (calculate_total_distance(customers, dist_matrix, best_solution_in_generated_pop) < calculate_total_distance(customers, dist_matrix, best_solution) and all_customers_served(best_solution_in_generated_pop)):
        best_solution = best_solution_in_generated_pop
        population = feasible_population
        fitness = [calculate_total_distance(customers, dist_matrix, feasible_solution) for feasible_solution in feasible_population]

    print(f"Best solution so far: {best_solution} with distance {calculate_total_distance(customers, dist_matrix, best_solution)}")
# Out:
# gen no:0
# pop no:0
# pop no:1
# pop no:2
# pop no:3
# pop no:4
# pop no:5
# pop no:6
# pop no:7
# pop no:8
# pop no:9
# pop no:10
# pop no:11
# pop no:12
# pop no:13
# pop no:14
# pop no:15
# pop no:16
# pop no:17
# pop no:18
# pop no:19
# Route 1 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 6 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 7 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 8 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 9 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 359.59
# Percentage of customers served: 24.24%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 6 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 7 (Load 58.0): 1 -> 39 -> 67 -> 55 -> 1 (Distance 58.8)
# Route 8 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 9 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 395.94
# Percentage of customers served: 24.24%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 5 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 6 (Load 69.0): 1 -> 72 -> 75 -> 22 -> 74 -> 1 (Distance 37.27)
# Total distance: 276.1
# Percentage of customers served: 17.17%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 5 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 305.64
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 3 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 4 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 155.41
# Percentage of customers served: 10.1%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 7 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 292.31
# Percentage of customers served: 22.22%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 5 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 305.64
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 22.0): 1 -> 63 -> 64 -> 90 -> 1 (Distance 65.54)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 9 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 10 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 441.92
# Percentage of customers served: 26.26%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 255.63
# Percentage of customers served: 15.15%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 5 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 305.64
# Percentage of customers served: 17.17%
# Route 1 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 2 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 3 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 6 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 7 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 8 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Total distance: 374.3
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 5 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 69.0): 1 -> 72 -> 75 -> 22 -> 74 -> 1 (Distance 37.27)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 330.54
# Percentage of customers served: 22.22%
# Route 1 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 2 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 64.92
# Percentage of customers served: 5.05%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 9 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 10 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 11 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 12 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 13 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Total distance: 618.17
# Percentage of customers served: 33.33%
# Route 1 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 2 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 3 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 290.62
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 225.13
# Percentage of customers served: 16.16%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 53.21
# Percentage of customers served: 5.05%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 6 (Load 36.0): 1 -> 52 -> 40 -> 58 -> 1 (Distance 35.38)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 8 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 9 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 10 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 11 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 12 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 13 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 559.06
# Percentage of customers served: 35.35%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 5 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 6 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 7 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 8 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 9 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 401.99
# Percentage of customers served: 24.24%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 36.0): 1 -> 52 -> 40 -> 58 -> 1 (Distance 35.38)
# Total distance: 149.72
# Percentage of customers served: 10.1%
# Best solution so far: [[6, 13], [82, 18, 94]] with distance 53.21314860847569
# gen no:1
# pop no:0
# pop no:1
# pop no:2
# pop no:3
# pop no:4
# pop no:5
# pop no:6
# pop no:7
# pop no:8
# pop no:9
# pop no:10
# pop no:11
# pop no:12
# pop no:13
# pop no:14
# pop no:15
# pop no:16
# pop no:17
# pop no:18
# pop no:19
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 222.46
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 222.46
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 7 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 287.96
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 149.18
# Percentage of customers served: 9.09%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 222.46
# Percentage of customers served: 12.12%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 5 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 249.19
# Percentage of customers served: 16.16%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 6 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 294.98
# Percentage of customers served: 15.15%
# Route 1 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 2 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 3 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 235.4
# Percentage of customers served: 14.14%
# Route 1 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 2 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 3 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 235.4
# Percentage of customers served: 14.14%
# Route 1 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 2 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 6 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 271.55
# Percentage of customers served: 18.18%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 222.46
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 149.18
# Percentage of customers served: 9.09%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 144.75
# Percentage of customers served: 8.08%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 7 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 287.96
# Percentage of customers served: 17.17%
# Route 1 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 2 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 6 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Total distance: 274.13
# Percentage of customers served: 14.14%
# Route 1 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 293.72
# Percentage of customers served: 15.15%
# Route 1 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 2 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 340.74
# Percentage of customers served: 20.2%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 6 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 294.98
# Percentage of customers served: 15.15%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 6 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 294.98
# Percentage of customers served: 15.15%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 212.93
# Percentage of customers served: 12.12%
# Best solution so far: [[6, 13], [82, 18, 94]] with distance 53.21314860847569
# gen no:2
# pop no:0
# pop no:1
# pop no:2
# pop no:3
# pop no:4
# pop no:5
# pop no:6
# pop no:7
# pop no:8
# pop no:9
# pop no:10
# pop no:11
# pop no:12
# pop no:13
# pop no:14
# pop no:15
# pop no:16
# pop no:17
# pop no:18
# pop no:19
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 7 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 287.37
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 227.74
# Percentage of customers served: 14.14%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 9 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 397.72
# Percentage of customers served: 21.21%
# Route 1 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 2 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 202.27
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 227.74
# Percentage of customers served: 14.14%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 4 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 5 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 224.74
# Percentage of customers served: 15.15%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 257.39
# Percentage of customers served: 15.15%
# Route 1 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 2 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 3 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 6 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 7 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 8 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 9 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Total distance: 402.23
# Percentage of customers served: 20.2%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Total distance: 114.34
# Percentage of customers served: 7.07%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 9 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 397.72
# Percentage of customers served: 21.21%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 261.81
# Percentage of customers served: 15.15%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 202.15
# Percentage of customers served: 12.12%
# Route 1 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 298.36
# Percentage of customers served: 17.17%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Total distance: 71.86
# Percentage of customers served: 4.04%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 7 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 8 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 9 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Total distance: 397.72
# Percentage of customers served: 21.21%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 261.81
# Percentage of customers served: 15.15%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 138.41
# Percentage of customers served: 10.1%
# Route 1 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 296.87
# Percentage of customers served: 18.18%
# Route 1 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 2 (Load 41.0): 1 -> 23 -> 56 -> 25 -> 1 (Distance 55.24)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 4 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 5 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 6 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 7 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 8 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Total distance: 315.13
# Percentage of customers served: 20.2%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 227.74
# Percentage of customers served: 14.14%
# Best solution so far: [[6, 13], [82, 94, 18]] with distance 71.20604148450933
# gen no:3
# pop no:0
# pop no:1
# pop no:2
# pop no:3
# pop no:4
# pop no:5
# pop no:6
# pop no:7
# pop no:8
# pop no:9
# pop no:10
# pop no:11
# pop no:12
# pop no:13
# pop no:14
# pop no:15
# pop no:16
# pop no:17
# pop no:18
# pop no:19
# Route 1 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 2 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 3 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 7 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 8 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 312.21
# Percentage of customers served: 20.2%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 213.15
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 213.15
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 7 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 273.67
# Percentage of customers served: 17.17%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Total distance: 231.21
# Percentage of customers served: 14.14%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Total distance: 212.96
# Percentage of customers served: 12.12%
# Route 1 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 2 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 7 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 8 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 312.21
# Percentage of customers served: 20.2%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 6 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Total distance: 247.36
# Percentage of customers served: 14.14%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 291.39
# Percentage of customers served: 18.18%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Total distance: 52.46
# Percentage of customers served: 4.04%
# Route 1 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 2 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 6 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 7 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 8 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 312.21
# Percentage of customers served: 20.2%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Total distance: 212.96
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 6 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 7 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 8 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 351.1
# Percentage of customers served: 20.2%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 7 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 273.67
# Percentage of customers served: 17.17%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Total distance: 212.96
# Percentage of customers served: 12.12%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 60.0): 1 -> 65 -> 71 -> 66 -> 1 (Distance 60.23)
# Total distance: 212.96
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 291.39
# Percentage of customers served: 18.18%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Route 7 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 8 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 9 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 10 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 11 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Total distance: 518.96
# Percentage of customers served: 29.29%
# Route 1 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 2 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 4 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Total distance: 151.52
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 209.81
# Percentage of customers served: 12.12%
# Best solution so far: [[6, 13], [82, 94, 18]] with distance 71.20604148450933
# gen no:4
# pop no:0
# pop no:1
# pop no:2
# pop no:3
# pop no:4
# pop no:5
# pop no:6
# pop no:7
# pop no:8
# pop no:9
# pop no:10
# pop no:11
# pop no:12
# pop no:13
# pop no:14
# pop no:15
# pop no:16
# pop no:17
# pop no:18
# pop no:19
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 58.0): 1 -> 39 -> 67 -> 55 -> 1 (Distance 58.8)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 244.06
# Percentage of customers served: 14.14%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 163.83
# Percentage of customers served: 9.09%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 150.29
# Percentage of customers served: 8.08%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 3 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 4 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 5 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 6 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 8 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Total distance: 338.62
# Percentage of customers served: 21.21%
# Route 1 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 2 (Load 56.0): 1 -> 28 -> 31 -> 50 -> 1 (Distance 51.76)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 147.09
# Percentage of customers served: 8.08%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 3 (Load 36.0): 1 -> 30 -> 51 -> 70 -> 1 (Distance 42.48)
# Route 4 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 7 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Total distance: 223.53
# Percentage of customers served: 18.18%
# Route 1 (Load 38.0): 1 -> 9 -> 34 -> 35 -> 1 (Distance 62.41)
# Route 2 (Load 55.0): 1 -> 12 -> 76 -> 79 -> 1 (Distance 42.62)
# Route 3 (Load 36.0): 1 -> 27 -> 69 -> 53 -> 1 (Distance 27.75)
# Route 4 (Load 48.0): 1 -> 29 -> 78 -> 68 -> 1 (Distance 45.75)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 6 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 7 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 8 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 9 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 367.93
# Percentage of customers served: 23.23%
# Route 1 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 2 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 4 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 5 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Total distance: 202.27
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 224.35
# Percentage of customers served: 14.14%
# Route 1 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 2 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 95.33
# Percentage of customers served: 5.05%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Route 5 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 6 (Load 27.0): 1 -> 54 -> 24 -> 80 -> 1 (Distance 40.31)
# Route 7 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 8 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 9 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 10 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 383.15
# Percentage of customers served: 22.22%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 224.35
# Percentage of customers served: 14.14%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Total distance: 222.5
# Percentage of customers served: 12.12%
# Route 1 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 2 (Load 27.0): 1 -> 21 -> 73 -> 57 -> 1 (Distance 39.36)
# Route 3 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Total distance: 222.5
# Percentage of customers served: 12.12%
# Route 1 (Load 47.0): 1 -> 5 -> 16 -> 17 -> 1 (Distance 52.77)
# Route 2 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 3 (Load 30.0): 1 -> 7 -> 8 -> 10 -> 1 (Distance 63.95)
# Route 4 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 5 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 6 (Load 63.0): 1 -> 47 -> 48 -> 1 (Distance 34.21)
# Route 7 (Load 20.0): 1 -> 45 -> 46 -> 60 -> 1 (Distance 49.32)
# Total distance: 324.98
# Percentage of customers served: 17.17%
# Route 1 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 2 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 3 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 148.21
# Percentage of customers served: 7.07%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 44.0): 1 -> 11 -> 20 -> 32 -> 1 (Distance 69.77)
# Route 3 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 4 (Load 58.0): 1 -> 39 -> 67 -> 55 -> 1 (Distance 58.8)
# Route 5 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Total distance: 225.99
# Percentage of customers served: 12.12%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 224.35
# Percentage of customers served: 14.14%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 224.35
# Percentage of customers served: 14.14%
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 34.0): 1 -> 19 -> 26 -> 1 (Distance 53.61)
# Route 3 (Load 35.0): 1 -> 36 -> 49 -> 1 (Distance 52.88)
# Route 4 (Load 28.0): 1 -> 62 -> 88 -> 1 (Distance 25.56)
# Route 5 (Load 55.0): 1 -> 82 -> 18 -> 94 -> 1 (Distance 34.96)
# Route 6 (Load 61.0): 1 -> 61 -> 85 -> 84 -> 1 (Distance 39.1)
# Total distance: 224.35
# Percentage of customers served: 14.14%
# Best solution so far: [[6, 13], [82, 94, 18]] with distance 71.20604148450933

# %%
formulate_solution(best_solution)
# Out:
# Route 1 (Load 26.0): 1 -> 6 -> 13 -> 1 (Distance 18.25)
# Route 2 (Load 55.0): 1 -> 82 -> 94 -> 18 -> 1 (Distance 52.95)
# Total distance: 71.21
# Percentage of customers served: 5.05%
